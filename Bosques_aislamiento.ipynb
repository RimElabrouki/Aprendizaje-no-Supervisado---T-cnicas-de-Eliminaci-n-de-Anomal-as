# %% [markdown]
# ## Bosques de Aislamiento

# %%
import time
import pandas as pd
from itertools import combinations
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, max_error, r2_score
from sklearn.ensemble import IsolationForest

# Cargar datos desde el archivo CSV
df_datos = pd.read_csv("datos/insurance.csv")

# Codificación One Hot para las columnas categóricas
columnas_categoricas = ['sex', 'smoker', 'region']
codificador_one_hot = OneHotEncoder(sparse=False)
codificacion_one_hot = codificador_one_hot.fit_transform(df_datos[columnas_categoricas])
arr_nombre_nuevas_columnas = codificador_one_hot.get_feature_names_out(columnas_categoricas)
df_nuevas_columnas_one_hot = pd.DataFrame(codificacion_one_hot, columns=arr_nombre_nuevas_columnas)
df_datos = pd.concat([df_datos, df_nuevas_columnas_one_hot], axis=1)

# Eliminar las columnas originales categóricas
df_datos.drop(columns=columnas_categoricas, inplace=True)

# Columnas incluyendo las codificadas con one-hot
columnas_especificas = df_datos.columns.tolist()

# Crear conjunto de datos solo con las columnas seleccionadas
df_X = pd.DataFrame(df_datos, columns=columnas_especificas)
df_y = pd.DataFrame(df_datos, columns=['charges'])

# Detección y eliminación de anomalías utilizando Bosques de Aislamiento
detector_anomalias = IsolationForest(contamination=0.05, random_state=100)
tiempo_inicio_anomalias = time.time()
df_X['anomalia'] = detector_anomalias.fit_predict(df_X)
tiempo_fin_anomalias = time.time()
tiempo_elim_anomalias = tiempo_fin_anomalias - tiempo_inicio_anomalias

# Filtrar los datos para eliminar anomalías
df_X_clean = df_X[df_X['anomalia'] != -1].copy()
df_y_clean = df_y.loc[df_X_clean.index]

# Eliminar la columna de anomalías
df_X_clean.drop(columns=['anomalia'], inplace=True)

# Llenar valores faltantes con SimpleImputer solo en las columnas numéricas
imputer = SimpleImputer(strategy='mean')
df_X_filled = pd.DataFrame(imputer.fit_transform(df_X_clean), columns=df_X_clean.columns)

# Normalizar variables independientes usando MinMaxScaler
scaler_X = MinMaxScaler()
df_X_scaled = pd.DataFrame(scaler_X.fit_transform(df_X_filled), columns=df_X_filled.columns)

# Dividir conjunto de datos en entrenamiento y prueba
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(df_X_scaled, df_y_clean, test_size=0.2, random_state=100)

# Lista para almacenar los resultados
resultados_knn = []

# Valores de k para KNN
valores_k = [1, 2, 3]

# Iterar sobre los valores de k
for k in valores_k:
    # Generar todas las combinaciones posibles de columnas
    for i in range(1, len(columnas_especificas) + 1):
        combinaciones_columnas = combinations(columnas_especificas, i)
        for combo in combinaciones_columnas:
            # Convertir la combinación en una lista para poder seleccionar las columnas del DataFrame
            combo_lista = list(combo)
            
            # Generar el modelo de regresión KNN y medir el tiempo de ejecución del modelo
            tiempo_inicio_modelo = time.time()
            model = KNeighborsRegressor(n_neighbors=k)
            model.fit(df_X_train[combo_lista], df_y_train.values.ravel())
            tiempo_fin_modelo = time.time()
            tiempo_modelo = tiempo_fin_modelo - tiempo_inicio_modelo
            
            # Realizar la prueba del modelo y medir el tiempo de ejecución de la prueba
            tiempo_inicio_prueba = time.time()
            arr_y_test_predicho = model.predict(df_X_test[combo_lista])
            tiempo_fin_prueba = time.time()
            tiempo_prueba = tiempo_fin_prueba - tiempo_inicio_prueba

            # Métricas de evaluación del modelo
            max_ea = max_error(df_y_test, arr_y_test_predicho)
            mae = mean_absolute_error(df_y_test, arr_y_test_predicho)
            mse = mean_squared_error(df_y_test, arr_y_test_predicho)
            r2 = r2_score(df_y_test, arr_y_test_predicho)

            # Almacenar resultados en la lista
            resultados_knn.append({
                'Valor_K': k,
                'Columnas': combo_lista,
                'Máximo_EA': max_ea,
                'EA_Medio': mae,
                'R^2': r2,
                'Tiempo_Modelo': tiempo_modelo,
                'Tiempo_Prueba': tiempo_prueba
            })

# Calcular el tiempo total de preprocesamiento
tiempo_preprocesamiento_total = tiempo_elim_anomalias
print(f"Tiempo de preprocesamiento total: {tiempo_preprocesamiento_total:.4f} segundos")
print("-" * 90)

# Crear un DataFrame a partir de la lista de resultados
df_resultados_knn = pd.DataFrame(resultados_knn)

# Imprimir resultados
for idx, row in df_resultados_knn.iterrows():
    print(f"Resultados para K={row['Valor_K']} y Columnas={row['Columnas']}:")
    print(f"   Máximo EA: {row['Máximo_EA']:.2f}")
    print(f"   EA Medio: {row['EA_Medio']:.2f}")
    print(f"   R^2: {row['R^2']:.4f}")
    print(f"   Tiempo de Generación del Modelo: {row['Tiempo_Modelo']:.4f} segundos")
    print(f"   Tiempo de Prueba del Modelo: {row['Tiempo_Prueba']:.4f} segundos")
    print("-" * 90)
# Out:
# C:\Users\rimel\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Tiempo de preprocesamiento total: 0.1638 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age']:
#    Máximo EA: 34985.06
#    EA Medio: 9457.18
#    R^2: -1.2093
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi']:
#    Máximo EA: 45437.08
#    EA Medio: 10848.34
#    R^2: -1.2270
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['children']:
#    Máximo EA: 37699.33
#    EA Medio: 10981.29
#    R^2: -1.4049
#    Tiempo de Generación del Modelo: 0.0025 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges']:
#    Máximo EA: 488.66
#    EA Medio: 26.34
#    R^2: 1.0000
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female']:
#    Máximo EA: 36536.07
#    EA Medio: 7696.94
#    R^2: -0.0979
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male']:
#    Máximo EA: 36536.07
#    EA Medio: 16994.75
#    R^2: -3.3311
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0019 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['smoker_no']:
#    Máximo EA: 23994.70
#    EA Medio: 5504.63
#    R^2: 0.4706
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['smoker_yes']:
#    Máximo EA: 25377.46
#    EA Medio: 5596.13
#    R^2: 0.4383
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0036 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northeast']:
#    Máximo EA: 35028.52
#    EA Medio: 7168.03
#    R^2: -0.0056
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_northwest']:
#    Máximo EA: 43982.67
#    EA Medio: 9455.91
#    R^2: -0.8354
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southeast']:
#    Máximo EA: 37055.18
#    EA Medio: 7157.30
#    R^2: -0.1163
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['region_southwest']:
#    Máximo EA: 36536.07
#    EA Medio: 7121.84
#    R^2: -0.0618
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['children', 'region_northwest']:
#    Máximo EA: 41022.14
#    EA Medio: 14561.34
#    R^2: -2.7781
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0016 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['children', 'region_southeast']:
#    Máximo EA: 41146.27
#    EA Medio: 12256.20
#    R^2: -1.8563
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['children', 'region_southwest']:
#    Máximo EA: 39306.68
#    EA Medio: 13334.14
#    R^2: -2.2271
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'sex_female']:
#    Máximo EA: 678.80
#    EA Medio: 43.02
#    R^2: 0.9999
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'sex_male']:
#    Máximo EA: 678.80
#    EA Medio: 43.02
#    R^2: 0.9999
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'smoker_no']:
#    Máximo EA: 535.59
#    EA Medio: 37.18
#    R^2: 0.9999
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'smoker_yes']:
#    Máximo EA: 535.59
#    EA Medio: 37.18
#    R^2: 0.9999
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0021 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'region_northeast']:
#    Máximo EA: 3598.54
#    EA Medio: 62.97
#    R^2: 0.9993
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'region_northwest']:
#    Máximo EA: 1073.51
#    EA Medio: 43.83
#    R^2: 0.9999
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'region_southeast']:
#    Máximo EA: 1891.52
#    EA Medio: 52.18
#    R^2: 0.9998
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['charges', 'region_southwest']:
#    Máximo EA: 585.75
#    EA Medio: 42.76
#    R^2: 0.9999
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'sex_male']:
#    Máximo EA: 36536.07
#    EA Medio: 7696.94
#    R^2: -0.0979
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'smoker_no']:
#    Máximo EA: 23425.55
#    EA Medio: 6338.24
#    R^2: 0.3783
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'smoker_yes']:
#    Máximo EA: 24378.37
#    EA Medio: 6382.12
#    R^2: 0.3520
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'region_northeast']:
#    Máximo EA: 36729.24
#    EA Medio: 8766.29
#    R^2: -0.5827
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0015 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'region_northwest']:
#    Máximo EA: 43982.67
#    EA Medio: 8844.52
#    R^2: -0.5807
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'region_southeast']:
#    Máximo EA: 37238.51
#    EA Medio: 7912.47
#    R^2: -0.2551
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_female', 'region_southwest']:
#    Máximo EA: 36536.07
#    EA Medio: 7489.17
#    R^2: -0.0828
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male', 'smoker_no']:
#    Máximo EA: 25377.46
#    EA Medio: 6302.36
#    R^2: 0.3747
#    Tiempo de Generación del Modelo: 0.0015 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male', 'smoker_yes']:
#    Máximo EA: 25377.46
#    EA Medio: 6057.24
#    R^2: 0.3125
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male', 'region_northeast']:
#    Máximo EA: 36729.24
#    EA Medio: 11277.99
#    R^2: -1.4432
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male', 'region_northwest']:
#    Máximo EA: 36318.86
#    EA Medio: 14318.12
#    R^2: -2.4500
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male', 'region_southeast']:
#    Máximo EA: 37238.51
#    EA Medio: 15322.67
#    R^2: -2.8047
#    Tiempo de Generación del Modelo: 0.0015 segundos
#    Tiempo de Prueba del Modelo: 0.0021 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['sex_male', 'region_southwest']:
#    Máximo EA: 36536.07
#    EA Medio: 14373.90
#    R^2: -2.4775
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['smoker_no', 'smoker_yes']:
#    Máximo EA: 23994.70
#    EA Medio: 5504.63
#    R^2: 0.4706
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'charges']:
#    Máximo EA: 7543.24
#    EA Medio: 530.13
#    R^2: 0.9863
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'sex_female']:
#    Máximo EA: 41862.36
#    EA Medio: 8100.26
#    R^2: -0.8189
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'sex_male']:
#    Máximo EA: 38941.09
#    EA Medio: 8366.51
#    R^2: -0.8853
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0015 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'smoker_no']:
#    Máximo EA: 24368.33
#    EA Medio: 4237.14
#    R^2: 0.3669
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'smoker_yes']:
#    Máximo EA: 23806.13
#    EA Medio: 4407.30
#    R^2: 0.3279
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'region_northeast']:
#    Máximo EA: 41862.36
#    EA Medio: 8559.06
#    R^2: -0.9549
#    Tiempo de Generación del Modelo: 0.0015 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'region_northwest']:
#    Máximo EA: 40055.98
#    EA Medio: 8335.66
#    R^2: -0.9241
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0015 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'region_southeast']:
#    Máximo EA: 38558.54
#    EA Medio: 9126.69
#    R^2: -1.0778
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'children', 'region_southwest']:
#    Máximo EA: 41862.36
#    EA Medio: 8299.87
#    R^2: -0.9313
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'sex_female']:
#    Máximo EA: 4680.19
#    EA Medio: 402.53
#    R^2: 0.9937
#    Tiempo de Generación del Modelo: 0.0025 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'sex_male']:
#    Máximo EA: 4680.19
#    EA Medio: 402.53
#    R^2: 0.9937
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'smoker_no']:
#    Máximo EA: 3768.47
#    EA Medio: 275.58
#    R^2: 0.9964
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'smoker_yes']:
#    Máximo EA: 3768.47
#    EA Medio: 275.58
#    R^2: 0.9964
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'region_northeast']:
#    Máximo EA: 14090.21
#    EA Medio: 455.15
#    R^2: 0.9860
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'region_northwest']:
#    Máximo EA: 3561.41
#    EA Medio: 329.18
#    R^2: 0.9959
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'region_southeast']:
#    Máximo EA: 4672.93
#    EA Medio: 412.00
#    R^2: 0.9934
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'charges', 'region_southwest']:
#    Máximo EA: 6144.29
#    EA Medio: 386.09
#    R^2: 0.9941
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'sex_male']:
#    Máximo EA: 38951.50
#    EA Medio: 9251.83
#    R^2: -1.1444
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'smoker_no']:
#    Máximo EA: 24961.19
#    EA Medio: 5164.27
#    R^2: 0.2462
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'smoker_yes']:
#    Máximo EA: 24368.33
#    EA Medio: 5312.73
#    R^2: 0.2228
#    Tiempo de Generación del Modelo: 0.0018 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'region_northeast']:
#    Máximo EA: 38941.09
#    EA Medio: 8188.04
#    R^2: -0.7934
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0015 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'region_northwest']:
#    Máximo EA: 38558.54
#    EA Medio: 9175.53
#    R^2: -1.0956
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'region_southeast']:
#    Máximo EA: 38951.50
#    EA Medio: 9622.98
#    R^2: -1.1634
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex_female', 'region_southwest']:
#    Máximo EA: 38951.50
#    EA Medio: 9265.91
#    R^2: -1.0769
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0016 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['age', 'sex
segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'smoker_no']:
#    Máximo EA: 31181.60
#    EA Medio: 6184.40
#    R^2: 0.2878
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'smoker_yes']:
#    Máximo EA: 31181.60
#    EA Medio: 6282.30
#    R^2: 0.2683
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'region_northeast']:
#    Máximo EA: 45437.08
#    EA Medio: 11295.27
#    R^2: -1.4236
#    Tiempo de Generación del Modelo: 0.0026 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'region_northwest']:
#    Máximo EA: 45437.08
#    EA Medio: 11706.82
#    R^2: -1.5162
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'region_southeast']:
#    Máximo EA: 45437.08
#    EA Medio: 11971.35
#    R^2: -1.6578
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'children', 'region_southwest']:
#    Máximo EA: 45437.08
#    EA Medio: 11110.44
#    R^2: -1.4185
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'sex_female']:
#    Máximo EA: 3372.85
#    EA Medio: 531.03
#    R^2: 0.9943
#    Tiempo de Generación del Modelo: 0.0022 segundos
#    Tiempo de Prueba del Modelo: 0.0013 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'sex_male']:
#    Máximo EA: 3372.85
#    EA Medio: 531.03
#    R^2: 0.9943
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'smoker_no']:
#    Máximo EA: 3768.47
#    EA Medio: 380.54
#    R^2: 0.9966
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'smoker_yes']:
#    Máximo EA: 3768.47
#    EA Medio: 380.54
#    R^2: 0.9966
#    Tiempo de Generación del Modelo: 0.0025 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'region_northeast']:
#    Máximo EA: 5418.33
#    EA Medio: 509.84
#    R^2: 0.9932
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0010 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'region_northwest']:
#    Máximo EA: 3372.85
#    EA Medio: 450.53
#    R^2: 0.9958
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'region_southeast']:
#    Máximo EA: 3553.87
#    EA Medio: 518.80
#    R^2: 0.9944
#    Tiempo de Generación del Modelo: 0.0015 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'charges', 'region_southwest']:
#    Máximo EA: 6395.21
#    EA Medio: 498.03
#    R^2: 0.9930
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0016 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'sex_female', 'sex_male']:
#    Máximo EA: 43728.63
#    EA Medio: 11657.85
#    R^2: -1.5246
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=1 y Columnas=['bmi', 'sex_female', 'smoker_no']:
#    Máximo EA: 30971.02
#    EA Medio: 5988.46
#    R^2: 0.4056
# ...
#    Máximo EA: 12852.47
#    EA Medio: 1401.46
#    R^2: 0.9337
#    Tiempo de Generación del Modelo: 0.0030 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'charges', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 12852.47
#    EA Medio: 1401.46
#    R^2: 0.9337
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 22696.76
#    EA Medio: 3413.89
#    R^2: 0.7071
#    Tiempo de Generación del Modelo: 0.0022 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0026 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0030 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0026 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0035 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 23896.66
#    EA Medio: 3769.32
#    R^2: 0.5867
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 12292.50
#    EA Medio: 1016.97
#    R^2: 0.9625
#    Tiempo de Generación del Modelo: 0.0026 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0036 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0025 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0029 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0030 segundos
#    Tiempo de Prueba del Modelo: 0.0024 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 26816.68
#    EA Medio: 5265.66
#    R^2: 0.5307
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 9096.53
#    EA Medio: 1095.42
#    R^2: 0.9699
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 10191.38
#    EA Medio: 949.75
#    R^2: 0.9634
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0020 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0015 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0010 segundos
#    Tiempo de Prueba del Modelo: 0.0036 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0030 segundos
#    Tiempo de Prueba del Modelo: 0.0025 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0026 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0027 segundos
#    Tiempo de Prueba del Modelo: 0.0028 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 24321.56
#    EA Medio: 3799.20
#    R^2: 0.6538
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0032 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 12852.47
#    EA Medio: 1401.46
#    R^2: 0.9337
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0035 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1349.56
#    R^2: 0.9170
#    Tiempo de Generación del Modelo: 0.0016 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 11056.18
#    EA Medio: 2045.70
#    R^2: 0.9164
#    Tiempo de Generación del Modelo: 0.0020 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
# Resultados para K=3 y Columnas=['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male', 'smoker_no', 'smoker_yes', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest']:
#    Máximo EA: 17709.19
#    EA Medio: 1658.00
#    R^2: 0.8899
#    Tiempo de Generación del Modelo: 0.0026 segundos
#    Tiempo de Prueba del Modelo: 0.0030 segundos
# ------------------------------------------------------------------------------------------
